# %%
import pandas as pd #is a standard way of naming
# %matplotlib inline

# %%
path= "data/pokemon_data.csv" #slash indicates that the data is a folder 
pokemon = pd.read_csv(path)

# %%
#series is a coloum just a different anotation 
pandas.core.frame.DataFrame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #series is a coloum just a different anotation
# ----> 2 pandas.core.frame.DataFrame
#
# NameError: name 'pandas' is not defined

# %%
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
pokemon['type1'] #bracket notation #bracket notation can handle spaces
# Out:
# 0        grass
# 1        grass
# 2        grass
# 3         fire
# 4         fire
#         ...
# 796      steel
# 797      grass
# 798       dark
# 799    psychic
# 800      steel
# Name: type1, Length: 801, dtype: object

# %%
#dot notation 
pokemon.type 1 #it thinks you have finished the function and thats why the error
# Out:
#   Cell In[10], line 2
#     pokemon.type 1
#                  ^
# SyntaxError: invalid syntax

# %%
pokemon.type1
# Out:
# 0        grass
# 1        grass
# 2        grass
# 3         fire
# 4         fire
#         ...
# 796      steel
# 797      grass
# 798       dark
# 799    psychic
# 800      steel
# Name: type1, Length: 801, dtype: object

# %%
display(pokemon)
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %%
pokemon.loc[pokemon.name == "Pikachu"]
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 24  ['Static', 'Lightningrod']          1.0           1.0             1.0
#
#     against_electric  against_fairy  against_fight  against_fire  \
# 24               0.5            1.0            1.0           1.0
#
#     against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 24             0.5            1.0  ...             50.0              25
#
#     sp_attack  sp_defense  speed     type1  type2  weight_kg  generation  \
# 24         50          50     90  electric    NaN        6.0           1
#
#     is_legendary
# 24             0
#
# [1 rows x 41 columns]

# %%
jap_pikachu = pokemon.loc[pokemon.name== "Pikachu" , "japanese_name"]
print(jap_pikachu)
# Out:
# 24    Pikachuピカチュウ
# Name: japanese_name, dtype: object

# %%
#min () and max() function 
weakest_pokemon = pokemon.hp.min()
strongest_pokemon= pokemon.hp.max()
print(weakest_pokemon) 
print(strongest_pokemon) #sometimes print is good to use to get the result
# Out:
# 1
# 255

# %%
wimpy_pokemon = pokemon.loc[pokemon.hp==1, 'name'].item() #item gives me the value inside the cell 
#without the item panda returns just the object 
wimpy_pokemon
# Out:
# 291    Shedinja
# Name: name, dtype: object

# %%
tough_pokemon = pokemon.loc[pokemon.hp==255, 'name'].item()
tough_pokemon
# Out:
# 'Blissey'

# %%
#getting the subsection of a dataframe - ie grabbing some rows 
pokemon_army_idx= pokemon[[p for p in pokemon. hp>150]] #two brackets cause we want a row and a column #outer is selecting and inner is giving the list comprehention
pokemon_army_idx
#we dont use the if statement here
# Out:
#                                       abilities  against_bug  against_dark  \
# 112  ['Natural Cure', 'Serene Grace', 'Healer']          1.0           1.0
# 142       ['Immunity', 'Thick Fat', 'Gluttony']          1.0           1.0
# 201                 ['Shadow Tag', 'Telepathy']          2.0           2.0
# 241  ['Natural Cure', 'Serene Grace', 'Healer']          1.0           1.0
# 320     ['Water Veil', 'Oblivious', 'Pressure']          1.0           1.0
# 593      ['Healer', 'Hydration', 'Regenerator']          1.0           1.0
# 717           ['Aura Break', 'Power Construct']          1.0           1.0
# 798                             ['Beast Boost']          2.0           0.5
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 112             1.0               1.0            1.0            2.0
# 142             1.0               1.0            1.0            2.0
# 201             1.0               1.0            1.0            0.5
# ...

# %%
pokemon_army_idx.name
# Out:
# 112      Chansey
# 142      Snorlax
# 201    Wobbuffet
# 241      Blissey
# 320      Wailord
# 593    Alomomola
# 717      Zygarde
# 798     Guzzlord
# Name: name, dtype: object

# %%
pokemon_army_idx.type1
# Out:
# 112     normal
# 142     normal
# 201    psychic
# 241     normal
# 320      water
# 593      water
# 717     dragon
# 798       dark
# Name: type1, dtype: object

# %%
pokemon_army_idx.type1.unique() #
# Out:
# array(['normal', 'psychic', 'water', 'dragon', 'dark'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(pokemon.hp, bins=25)
plt.xlabel('HP')
plt.ylabel("Number of Pokemon")
plt.title("Distribution of HP over all Pokemon")
# Out:
# Text(0.5, 1.0, 'Distribution of HP over all Pokemon')

# %%
pokemon_groupings = pokemon.groupby('type1')

# %%
water_pokemon= pokemon_groupings.get_group('water')
fire_pokemon = pokemon_groupings.get_group('fire')

# %%
type(water_pokemon)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.hist(water_pokemon.hp, bins=25, label='water')
plt.hist(fire_pokemon.hp, bins=25, label='Fire')
plt.xlabel("HP")
plt.ylabel("Number of Pokemon")
plt.legend()
